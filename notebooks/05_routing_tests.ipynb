# %%
# %pip install osmnx networkx geopandas folium shapely numpy ipyleaflet
# Out:
# Requirement already satisfied: osmnx in ./venv/lib/python3.11/site-packages (2.0.6)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (3.5)
# Requirement already satisfied: geopandas in ./venv/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: folium in ./venv/lib/python3.11/site-packages (0.20.0)
# Requirement already satisfied: shapely in ./venv/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (2.3.5)
# Requirement already satisfied: ipyleaflet in ./venv/lib/python3.11/site-packages (0.20.0)
# Requirement already satisfied: pandas>=1.4 in ./venv/lib/python3.11/site-packages (from osmnx) (2.3.3)
# Requirement already satisfied: requests>=2.27 in ./venv/lib/python3.11/site-packages (from osmnx) (2.32.5)
# Requirement already satisfied: pyogrio>=0.7.2 in ./venv/lib/python3.11/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in ./venv/lib/python3.11/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: branca>=0.6.0 in ./venv/lib/python3.11/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in ./venv/lib/python3.11/site-packages (from folium) (3.1.6)
# Requirement already satisfied: xyzservices in ./venv/lib/python3.11/site-packages (from folium) (2025.10.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in ./venv/lib/python3.11/site-packages (from ipyleaflet) (8.1.8)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in ./venv/lib/python3.11/site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in ./venv/lib/python3.11/site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: comm>=0.1.3 in ./venv/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./venv/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./venv/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./venv/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./venv/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: certifi in ./venv/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests>=2.27->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests>=2.27->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: decorator>=4.3.2 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in ./venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.15.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.1)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import folium
from shapely.geometry import LineString
import numpy as np

from ipyleaflet import Map, Marker, basemaps, basemap_to_tiles
from ipywidgets import HTML

# %%
import os
os.getcwd()
os.chdir('/home/kuldeep-chamoli/Desktop/GIS/GIS/')

# %%
G = ox.load_graphml("data/processed/roads_with_env.graphml")

for u, v, k, d in G.edges(keys=True, data=True):
    d["ndvi"]   = float(d.get("ndvi") or 0.0)
    d["aqi"]    = float(d.get("aqi") or 0.0)
    d["length"] = float(d.get("length") or 1.0)

print("Graph loaded:", len(G.nodes), "nodes |", len(G.edges), "edges")
# Out:
# Graph loaded: 154475 nodes | 392383 edges

# %%
def greenness_cost(ndvi, length):
    ndvi = max(0, min(1, ndvi))
    return length * (1 - ndvi)

def pollution_cost(aqi, length):
    return length * (1 + (aqi / 100))

def hybrid_cost(ndvi, aqi, length, w_ndvi=0.7, w_aqi=0.3):
    return w_ndvi * greenness_cost(ndvi, length) + \
           w_aqi * pollution_cost(aqi, length)

def assign_green_cost(G, w_ndvi=0.7, w_aqi=0.3):
    for u, v, k, d in G.edges(keys=True, data=True):
        d["green_cost"] = hybrid_cost(d["ndvi"], d["aqi"], d["length"], w_ndvi, w_aqi)

assign_green_cost(G)
print("Green cost assigned.")
# Out:
# Green cost assigned.

# %%
def greenness_cost(ndvi, length):
    ndvi = max(0.0, min(1.0, ndvi))
    return length * (1 - ndvi)

def pollution_cost(aqi, length):
    return length * (1 + (aqi / 100))

def hybrid_cost(ndvi, aqi, length, w_ndvi=0.7, w_aqi=0.3):
    return w_ndvi * greenness_cost(ndvi, length) + \
           w_aqi * pollution_cost(aqi, length)

def assign_edge_costs(G, w_ndvi=0.7, w_aqi=0.3):
    for _, _, _, d in G.edges(keys=True, data=True):
        d["green_cost"] = hybrid_cost(d["ndvi"], d["aqi"], d["length"], w_ndvi, w_aqi)

assign_edge_costs(G)
print("Green cost assigned.")
# Out:
# Green cost assigned.

# %%
boundary = gpd.read_file("data/raw/bengaluru_boundary.geojson")
center = boundary.geometry.centroid.iloc[0]
center_lat, center_lon = center.y, center.x

(center_lat, center_lon)
# Out:
# /tmp/ipykernel_33422/348072979.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = boundary.geometry.centroid.iloc[0]
# (12.976302529390086, 77.60301428375439)

# %%
origin = None
destination = None
origin_marker = None
destination_marker = None
click_count = 0

mclick = Map(
    basemap=basemap_to_tiles(basemaps.OpenStreetMap.Mapnik),
    center=(center_lat, center_lon),
    zoom=12
)

msg = HTML("<b>Click on the map to select ORIGIN</b>")
mclick.add(msg)

def handle_click(**kwargs):
    global click_count, origin, destination, origin_marker, destination_marker

    if kwargs.get("type") == "click":
        lat = kwargs.get("lat")
        lon = kwargs.get("lng")
        click_count += 1
        
        # ORIGIN
        if click_count == 1:
            origin = (lat, lon)
            origin_marker = Marker(location=origin, draggable=False)
            mclick.add(origin_marker)
            msg.value = f"<b>Origin set:</b> {origin}<br>Now click for DESTINATION."
        
        # DESTINATION
        elif click_count == 2:
            destination = (lat, lon)
            destination_marker = Marker(location=destination, draggable=False)
            mclick.add(destination_marker)
            msg.value = (
                f"<b>Destination set:</b> {destination}<br>"
                "<b>Both points selected!</b>"
            )
            
            mclick.on_interaction(lambda **kw: None)  # disable further clicks

mclick.on_interaction(handle_click)

mclick
# Out:
# Map(center=[12.976302529390086, 77.60301428375439], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
import geopandas as gpd

# Load Bengaluru boundary
boundary = gpd.read_file("data/raw/bengaluru_boundary.geojson")

# Compute approximate center of the city
city_center = boundary.geometry.centroid.iloc[0]
center_lat, center_lon = city_center.y, city_center.x

center_lat, center_lon
# Out:
# /tmp/ipykernel_33422/389038564.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_center = boundary.geometry.centroid.iloc[0]
# (12.976302529390086, 77.60301428375439)

# %%
print("Enter coordinates in the format: lat, lon")

# Origin input
orig_input = input("Enter ORIGIN (lat,lon): ").strip()
origin = tuple(map(float, orig_input.split(",")))

# Destination input
dest_input = input("Enter DESTINATION (lat,lon): ").strip()
destination = tuple(map(float, dest_input.split(",")))

print("\nSelected Points:")
print("Origin     :", origin)
print("Destination:", destination)
# Out:
# Enter coordinates in the format: lat, lon
#
# Selected Points:
# Origin     : (12.9352, 77.6245)
# Destination: (12.9784, 77.6408)

# %%
origin, destination
# Out:
# ((12.9352, 77.6245), (12.9784, 77.6408))

# %%
def nearest_node(G, lat, lon):
    return ox.distance.nearest_nodes(G, lon, lat)

def compute_path(G, origin, destination, weight):
    o = nearest_node(G, *origin)
    d = nearest_node(G, *destination)
    return nx.shortest_path(G, o, d, weight=weight)

# %%
shortest = compute_path(G, origin, destination, "length")
greenest = compute_path(G, origin, destination, "green_cost")

print("Shortest path nodes:", len(shortest))
print("Greenest path nodes:", len(greenest))
# Out:
# Shortest path nodes: 41
# Greenest path nodes: 41

# %%
def path_to_linestring(G, path):
    coords = []
    for u, v in zip(path[:-1], path[1:]):
        data = G.get_edge_data(u, v)
        k = list(data.keys())[0]
        geom = data[k].get("geometry")
        if geom:
            coords.extend(list(geom.coords))
        else:
            coords.append((G.nodes[u]["x"], G.nodes[u]["y"]))
    return LineString(coords)

ls_short = path_to_linestring(G, shortest)
ls_green = path_to_linestring(G, greenest)

# %%
m = folium.Map(location=origin, zoom_start=13)

folium.GeoJson(
    ls_short,
    name="Shortest Route",
    style_function=lambda x: {"color": "red", "weight": 5}
).add_to(m)

folium.GeoJson(
    ls_green,
    name="Greenest Route",
    style_function=lambda x: {"color": "green", "weight": 5}
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06b245910edf5c1d9839e2195b27d511 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06b245910edf5c1d9839e2195b27d511&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06b245910edf5c1d9839e2195b27d511 = L.map(
#                 &quot;map_06b245910edf5c1d9839e2195b27d511&quot;,
#                 {
#                     center: [12.9352, 77.6245],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61198a96a0af50eec8c330153ac0d8a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61198a96a0af50eec8c330153ac0d8a2.addTo(map_06b245910edf5c1d9839e2195b27d511);
#
#
#         function geo_json_b3f855bc3627cd6552f0c24bc7e251b2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;weight&quot;: 5};
#             }
#         }
#
#         function geo_json_b3f855bc3627cd6552f0c24bc7e251b2_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b3f855bc3627cd6552f0c24bc7e251b2 = L.geoJson(null, {
#                 onEachFeature: geo_json_b3f855bc3627cd6552f0c24bc7e251b2_onEachFeature,
#
#                 style: geo_json_b3f855bc3627cd6552f0c24bc7e251b2_styler,
#             ...{
# }
#         });
#
#         function geo_json_b3f855bc3627cd6552f0c24bc7e251b2_add (data) {
#             geo_json_b3f855bc3627cd6552f0c24bc7e251b2
#                 .addData(data);
#         }
#             geo_json_b3f855bc3627cd6552f0c24bc7e251b2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[77.6244413, 12.9351903], [77.6243708, 12.9352411], [77.6254105, 12.9361127], [77.6268138, 12.9372333], [77.6268259, 12.9372429], [77.6268738, 12.9372808], [77.6268738, 12.9372808], [77.6269369, 12.9373325], [77.6269885, 12.9373785], [77.627084, 12.9374592], [77.62723, 12.9375825], [77.6273983, 12.9377023], [77.6276162, 12.9378348], [77.6278228, 12.9379459], [77.6282821, 12.9381715], [77.6285082, 12.9382733], [77.6287044, 12.9383498], [77.6287044, 12.9383498], [77.6291682, 12.9384931], [77.6293771, 12.938538], [77.62954, 12.938548], [77.6296832, 12.9385483], [77.6296832, 12.9385483], [77.6303164, 12.9385257], [77.6305721, 12.9385254], [77.6305721, 12.9385254], [77.6308242, 12.9385597], [77.6311049, 12.9385683], [77.6313323, 12.9385706], [77.6315238, 12.9385772], [77.6317897, 12.9385825], [77.6320374, 12.9385822], [77.6325141, 12.9385742], [77.6325528, 12.9385736], [77.632689, 12.9385725], [77.632689, 12.9385725], [77.6331222, 12.9385691], [77.6333035, 12.9385672], [77.6336129, 12.938565], [77.6